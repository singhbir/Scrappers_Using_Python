# %%
import requests

# %%
import bs4

# %%
res=requests.get('https://www.amazon.in/headphones/b/ref=sd_allcat_sbc_tvelec_headphones?ie=UTF8&node=1388921031')

# %%
type(res)
# Out:
# requests.models.Response

# %%
res.text
# Out:
# '\n<!doctype html><html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"><!--  emit CSM JS -->\n    <style>\n[class*=scx-line-clamp-]{overflow:hidden}.scx-offscreen-truncate{position:relative;left:-1000000px}.scx-line-clamp-1{max-height:16.75px}.scx-truncate-medium.scx-line-clamp-1{max-height:20.34px}.scx-truncate-small.scx-line-clamp-1{max-height:13px}.scx-line-clamp-2{max-height:35.5px}.scx-truncate-medium.scx-line-clamp-2{max-height:41.67px}.scx-truncate-small.scx-line-clamp-2{max-height:28px}.scx-line-clamp-3{max-height:54.25px}.scx-truncate-medium.scx-line-clamp-3{max-height:63.01px}.scx-truncate-small.scx-line-clamp-3{max-height:43px}.scx-line-clamp-4{max-height:73px}.scx-truncate-medium.scx-line-clamp-4{max-height:84.34px}.scx-truncate-small.scx-line-clamp-4{max-height:58px}.scx-line-clamp-5{max-height:91.75px}.scx-truncate-medium.scx-line-clamp-5{max-height:105.68px}.scx-truncate-small.scx-line-clamp-5
# ...

# %%
soup =bs4.BeautifulSoup(res.text,'lxml')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'HTML_FORMATTERS',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'XML_FORMATTERS',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_attr_value_as_string',
#  '_attribute_checker',
#  '_check_markup_is_url',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_formatter_for_name',
#  '_is_xml',
#  '_lastRecursiveChild',
# ...

# %%
hello=soup.find_all("span")

# %%
hello
# Out:
# [<span class="nav-sprite nav-logo-base"></span>,
#  <span class="nav-sprite nav-logo-ext"></span>,
#  <span class="nav-sprite nav-logo-locale"></span>,
#  <span class="nav-search-label">Audio Headphones</span>,
#  <span id="searchDropdownDescription" style="display:none">Select the department you want to search in</span>,
#  <span class="nav-search-submit-text nav-sprite" id="nav-search-submit-text">
#            Go
#          </span>,
#  <span class="nav-line-1">Hello. Sign in</span>,
#  <span class="nav-line-2">Your Orders<span class="nav-icon nav-arrow"></span>
#  </span>,
#  <span class="nav-icon nav-arrow"></span>,
#  <span class="nav-line-3">Sign in</span>,
#  <span class="nav-line-4">Your Orders</span>,
#  <span class="nav-line-1">Try</span>,
#  <span class="nav-line-2">Prime<span class="nav-icon nav-arrow"></span>
#  </span>,
#  <span class="nav-icon nav-arrow"></span>,
#  <span class="nav-line-1">Your</span>,
# ...

# %%
final=[]
for h in hello:
    final.append(h.get("class"))

# %%
final
# Out:
# [['nav-sprite', 'nav-logo-base'],
#  ['nav-sprite', 'nav-logo-ext'],
#  ['nav-sprite', 'nav-logo-locale'],
#  ['nav-search-label'],
#  None,
#  ['nav-search-submit-text', 'nav-sprite'],
#  ['nav-line-1'],
#  ['nav-line-2'],
#  ['nav-icon', 'nav-arrow'],
#  ['nav-line-3'],
#  ['nav-line-4'],
#  ['nav-line-1'],
#  ['nav-line-2'],
#  ['nav-icon', 'nav-arrow'],
#  ['nav-line-1'],
#  ['nav-line-2'],
#  ['nav-icon', 'nav-arrow'],
#  ['nav-line-1'],
#  ['nav-line-2'],
#  ['nav-icon', 'nav-arrow'],
#  ['nav-cart-icon', 'nav-sprite'],
#  ['nav-cart-count', 'nav-cart-0'],
#  ['nav-line-1'],
#  ['nav-line-2'],
#  ['nav-icon', 'nav-arrow'],
#  ['nav-a-content'],
#  ['nav-a-content'],
#  ['nav-arrow'],
#  ['nav-a-content'],
#  ['nav-arrow'],
#  ['nav-a-content'],
#  ['nav-arrow'],
#  ['nav-a-content'],
#  ['nav-arrow'],
#  ['nav-a-content'],
#  ['nav-arrow'],
#  ['nav-a-content'],
#  ['nav-arrow'],
#  ['nav-a-content'],
#  ['nav-arrow'],
#  ['nav-a-content'],
#  ['nav-arrow'],
# ...

# %%
f=soup.find_all("span")

# %%
f
# Out:
# [<span class="nav-sprite nav-logo-base"></span>,
#  <span class="nav-sprite nav-logo-ext"></span>,
#  <span class="nav-sprite nav-logo-locale"></span>,
#  <span class="nav-search-label">Audio Headphones</span>,
#  <span id="searchDropdownDescription" style="display:none">Select the department you want to search in</span>,
#  <span class="nav-search-submit-text nav-sprite" id="nav-search-submit-text">
#            Go
#          </span>,
#  <span class="nav-line-1">Hello. Sign in</span>,
#  <span class="nav-line-2">Your Orders<span class="nav-icon nav-arrow"></span>
#  </span>,
#  <span class="nav-icon nav-arrow"></span>,
#  <span class="nav-line-3">Sign in</span>,
#  <span class="nav-line-4">Your Orders</span>,
#  <span class="nav-line-1">Try</span>,
#  <span class="nav-line-2">Prime<span class="nav-icon nav-arrow"></span>
#  </span>,
#  <span class="nav-icon nav-arrow"></span>,
#  <span class="nav-line-1">Your</span>,
# ...

# %%
p=soup.find_all('span', {'class': 'a-size-base a-color-price acs_product-price__buying'})

# %%
p=soup.find_all('span', {'class': 'a-size-base a-color-price acs_product-price__buying'})

# %%
ln=[]
for j in p:
    ln.append(j.text)

# %%
for k in p:
    print(k.text)
# Out:
# ₹ 399.00
# ₹ 599.00
# ₹ 375.00
# ₹ 799.00
# ₹ 499.00
# ₹ 299.00
# ₹ 399.00
# ₹ 599.00
# ₹ 599.00
# ₹ 499.00
# ₹ 1,499.00
# ₹ 799.00
# ₹ 599.00
# ₹ 732.00
# ₹ 1,599.00
# ₹ 999.00
# ₹ 699.00
# ₹ 899.00
# ₹ 799.00
# ₹ 2,277.00
# ₹ 26,425.00
# ₹ 4,999.00
# ₹ 7,488.00
# ₹ 2,999.00
# ₹ 2,499.00
# ₹ 2,200.00
# ₹ 2,499.00
# ₹ 29,990.00
# ₹ 549.00
# ₹ 2,250.00
# ₹ 999.00
# ₹ 349.00
# ₹ 1,150.00
# ₹ 399.00
# ₹ 999.00
# ₹ 259.00
# ₹ 799.00
# ₹ 180.00
# ₹ 4,399.00
# ₹ 2,999.00
# ₹ 669.00
# ₹ 2,917.00
# ₹ 184.00
# ₹ 199.00
# ₹ 699.00
# ₹ 2,250.00
# ₹ 570.00
# ₹ 2,917.00
# ₹ 699.00
# ₹ 2,799.00
# ₹ 799.00
# ₹ 599.00
# ₹ 697.00
# ₹ 797.00
# ₹ 899.00
# ₹ 1,999.00
# ₹ 2,499.00
# ₹ 1,999.00
# ₹ 999.00
# ₹ 699.00
# ₹ 2,274.00
# ₹ 3,199.00
# ₹ 2,299.00
# ₹ 2,097.00
# ₹ 3,699.00
# ₹ 2,919.00
# ₹ 1,649.00
# ₹ 1,946.00
# ₹ 1,739.00

# %%
type(p)
# Out:
# bs4.element.ResultSet

# %%
lln=[w.replace('\x', '') for w in ln]
# Out:
#   File "<ipython-input-183-11973d156236>", line 1
#     lln=[w.replace('\x', '') for w in ln]
#                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: truncated \xXX escape

# %%
for x in p:
    print(x.text())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-ea1fcba76092> in <module>
#       1 for x in p:
# ----> 2     print(x.text())
#       3
#
# TypeError: 'str' object is not callable

# %%
name=soup.find_all('a', {'class':'a-link-normal'},'title')

# %%
name
# Out:
# [<a class="a-link-normal" href="/Mi-Earphones-Basic-Mic-Black/dp/B07CD2BN46" title="Mi  Earphones Basic with Mic (Black)">
#  <span class="a-size-small">Mi  Earphones Basic with Mic (Black)</span>
#  </a>,
#  <a class="a-link-normal" href="/BassHeads-225-Super-Extra-Headphones/dp/B01M9C51T9" title="boAt BassHeads 225 in-Ear Super Extra Bass Headphones (Black)">
#  <span class="a-size-small">boAt BassHeads 225 in-Ear Super Extra...</span>
#  </a>,
#  <a class="a-link-normal" href="/boAt-BassHeads-100-Headphones-White/dp/B07234XXJF" title="boAt BassHeads 100 in-Ear Headphones with Mic (White)">
#  <span class="a-size-small">boAt BassHeads 100 in-Ear Headphones...</span>
#  </a>,
#  <a class="a-link-normal" href="/JBL-C100SI-Ear-Headphones-Black/dp/B01DEWVZ2C" title="JBL C100SI In-Ear Headphones with Mic (Black)">
#  <span class="a-size-small">JBL C100SI In-Ear Headphones with Mic</span>
#  </a>,
# ...

# %%
type(name)
# Out:
# bs4.element.ResultSet

# %%
lp=[]
for x in name:
    lp.append(x.text)

# %%
for x,y in zip(lp[:69],ln):
    print(x,y)
# Out:
# Mi  Earphones Basic with Mic (Black)
#  ₹ 399.00
#
# boAt BassHeads 225 in-Ear Super Extra...
#  ₹ 599.00
#
# boAt BassHeads 100 in-Ear Headphones...
#  ₹ 375.00
#
# JBL C100SI In-Ear Headphones with Mic
#  ₹ 799.00
#
# boAt BassHeads 100 in-Ear Headphones...
#  ₹ 499.00
#
# Ant Audio Thump 504 Wired Portable...
#  ₹ 299.00
#
# Mi Earphones Basic with Mic (Red)
#  ₹ 399.00
#
# Sony MDR-ZX110A On-Ear Stereo...
#  ₹ 599.00
#
# boAt BassHeads 225 Special Edition...
#  ₹ 599.00
#
# Ant Audio W56 Wired Metal in Ear...
#  ₹ 499.00
#
# Boat Rockerz 400 On-Ear Bluetooth...
#  ₹ 1,499.00
#
# Boat BassHeads 900 Wired Headphone...
#  ₹ 799.00
#
# boAt Bass Heads 225 in-Ear Bass...
#  ₹ 599.00
#
# Sennheiser CX 180 Street II In-Ear...
#  ₹ 732.00
#
# Sennheiser CX 275 S In -Ear Universal...
#  ₹ 1,599.00
#
# Ant Audio Thump 504 Wired Portable...
#  ₹ 999.00
#
# Leaf Sport Wireless Bluetooth Earphone
#  ₹ 699.00
#
# Mi Earphones with Mic (Black)
#  ₹ 899.00
#
# House of Marley Smile Jamaica...
# ...

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
l2[0]
# Out:
# '₹\xa0399.00 \xa0'

# %%
len(p)
# Out:
# 69

# %%
for k in lp[:69]:
    print(k)
# Out:
# Mi  Earphones Basic with Mic (Black)
# boAt BassHeads 225 in-Ear Super Extra...
# Boat
# boAt BassHeads 100 in-Ear Headphones...
# Boat
# JBL C100SI In-Ear Headphones with Mic
# boAt BassHeads 100 in-Ear Headphones...
# Boat
# Ant Audio Thump 504 Wired Portable...
# Mi Earphones Basic with Mic (Red)
# Sony MDR-ZX110A On-Ear Stereo...
# boAt BassHeads 225 Special Edition...
# Boat
# Ant Audio W56 Wired Metal in Ear...
# Boat Rockerz 400 On-Ear Bluetooth...
# Boat BassHeads 900 Wired Headphone...
# boAt Bass Heads 225 in-Ear Bass...
# Boat
# Sennheiser CX 180 Street II In-Ear...
# Sennheiser CX 275 S In -Ear Universal...
# Ant Audio Thump 504 Wired Portable...
# Leaf Sport Wireless Bluetooth Earphone
# Mi Earphones with Mic (Black)
# House of Marley Smile Jamaica...
# JBL C100SI In-Ear Headphones with Mic
# boAt Rockerz 255 Sports Bluetooth...
# Boat
# Bose Quiet Comfort 35 II Wireless...
# Noise Shots X5 Truly Wireless...
# Sennheiser HD 4.40-BT Bluetooth...
# ...
