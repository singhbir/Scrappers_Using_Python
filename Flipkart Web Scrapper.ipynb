# %%
import requests

# %%
import bs4

# %%
res=requests.get('https://www.flipkart.com/search?q=laptops&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_2_0&otracker1=AS_Query_TrendingAutoSuggest_2_0&as-pos=2&as-type=TRENDING')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <title>
#    Learn code online | A complete programming video tutorial site
#   </title>
#   <meta content="Learncodeonline.in is a platform to learn about programming and make projects with that knowledge. Access high quality videos at reasonable price." name="description"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="LearnCodeOnline" itemprop="title name" name="twitter:title" property="og:title"/>
#   <meta content="Learn code online | A complete programming video tutorial site" itemprop="title name" property="og:title"/>
#   <meta content="courses.learncodeonline.in" property="og:url"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
soup=bs4.BeautifulSoup(res.text,'lxml')

# %%
l=soup.find_all('div',{'class':'_3wU53n'})

# %%
p=soup.find_all('div',{'class':'_1vC4OE _2rQ-NK'})

# %%
li=[]
for i in p:
    li.append(i.text)

# %%
li
# Out:
# ['₹32,259',
#  '₹14,990',
#  '₹41,990',
#  '₹27,990',
#  '₹18,990',
#  '₹62,990',
#  '₹23,990',
#  '₹26,990',
#  '₹43,990',
#  '₹24,990',
#  '₹26,490',
#  '₹25,990',
#  '₹17,990',
#  '₹89,990',
#  '₹32,490',
#  '₹27,990',
#  '₹59,990',
#  '₹79,990',
#  '₹41,990',
#  '₹32,990',
#  '₹36,990',
#  '₹20,990',
#  '₹14,990',
#  '₹41,990']

# %%
l2=[]
for i in l:
    l2.append(i.text)

# %%
l2=[i.split("-")[0] for i in l2]

# %%
len(l2)
# Out:
# 24

# %%
len(li)
# Out:
# 24

# %%
for i,j in zip(l2,li):
    print(i,":",j)
# Out:
# HP 15 Core i3 7th Gen  : ₹32,259
# Acer Aspire 3 Celeron Dual Core  : ₹14,990
# HP 15q Core i5 7th Gen  : ₹41,990
# HP 15q Core i3 7th Gen  : ₹27,990
# Acer Aspire 3 Pentium Quad Core  : ₹18,990
# Apple MacBook Air Core i5 5th Gen  : ₹62,990
# HP 15 APU Dual Core A6  : ₹23,990
# Dell Vostro 15 3000 Core i3 6th Gen  : ₹26,990
# Lenovo Ideapad 330 Core i5 8th Gen  : ₹43,990
# HP 15 APU Dual Core A9  : ₹24,990
# Dell Inspiron 14 3000 Series Core i3 7th Gen  : ₹26,490
# Lenovo Ideapad 320 Core i3 6th Gen  : ₹25,990
# Asus APU Quad Core E2  : ₹17,990
# Acer Predator Helios 300 Core i7 8th Gen  : ₹89,990
# HP 15q Core i3 7th Gen  : ₹32,490
# HP 14q Core i3 7th Gen  : ₹27,990
# Acer Nitro 5 Ryzen 5 Quad Core  : ₹59,990
# Acer Predator Helios 300 Core i5 8th Gen  : ₹79,990
# HP 15q Core i5 8th Gen  : ₹41,990
# HP 15q Core i3 7th Gen  : ₹32,990
# Lenovo Ideapad 130 Core i5 8th Gen  : ₹36,990
# Dell Inspiron Pentium Quad Core  : ₹20,990
# Asus Vivo Celeron Dual Core  : ₹14,990
# ...

# %%
import pandas as pd

# %%
mainlist=pd.DataFrame({'LAPTOPS':l2,'PRICE':li})

# %%
mainlist.to_excel('laptops_price.xls')

# %%
mainlist
# Out:
#                                           LAPTOPS    PRICE
# 0                          HP 15 Core i3 7th Gen   ₹32,259
# 1                Acer Aspire 3 Celeron Dual Core   ₹14,990
# 2                         HP 15q Core i5 7th Gen   ₹41,990
# 3                         HP 15q Core i3 7th Gen   ₹27,990
# 4                Acer Aspire 3 Pentium Quad Core   ₹18,990
# 5              Apple MacBook Air Core i5 5th Gen   ₹62,990
# 6                         HP 15 APU Dual Core A6   ₹23,990
# 7            Dell Vostro 15 3000 Core i3 6th Gen   ₹26,990
# 8             Lenovo Ideapad 330 Core i5 8th Gen   ₹43,990
# 9                         HP 15 APU Dual Core A9   ₹24,990
# 10  Dell Inspiron 14 3000 Series Core i3 7th Gen   ₹26,490
# 11            Lenovo Ideapad 320 Core i3 6th Gen   ₹25,990
# 12                         Asus APU Quad Core E2   ₹17,990
# 13      Acer Predator Helios 300 Core i7 8th Gen   ₹89,990
# 14                        HP 15q Core i3 7th Gen   ₹32,490
# ...
